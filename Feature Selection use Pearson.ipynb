# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("datakipasnew.csv") 
data
# Out:
#     year  month  day  voltage  current  power  frequency  powerfactor  Energy
# 0   2021      2   20   202.30     0.03   0.80      50.00         0.13    0.35
# 1   2021      2   21   197.30     0.16  30.90      50.00         0.97    0.26
# 2   2021      2   22   200.40     0.03   0.80      50.00         0.13    0.35
# 3   2021      2   23   207.20     0.16  29.20      49.80         0.89    0.27
# 4   2021      2   24   211.50     0.16  29.40      49.90         0.88    0.40
# 5   2021      2   25   194.60     0.14  23.60      50.00         0.85    0.66
# 6   2021      2   26   193.50     0.17  31.80      49.90         0.98    0.66
# 7   2021      2   27   188.20     0.14  22.50      50.00         0.86    0.64
# 8   2021      2   28   185.30     0.16  28.50      50.00         0.98    0.63
# 9   2021      3    1   191.50     0.17  31.00      50.00         0.98    0.49
# 10  2021      3    2   195.00     0.15  24.20      50.00         0.86    0.61
# ...

# %%
df_factors1 = data.loc[:,["year","month","day","voltage","current","power","frequency","powerfactor","Energy"]].iloc[1:,:]
df_factors1.index=range(0,len(df_factors1))
df_factors1
# Out:
#     year  month  day  voltage  current  power  frequency  powerfactor  Energy
# 0   2021      2   21   197.30     0.16  30.90      50.00         0.97    0.26
# 1   2021      2   22   200.40     0.03   0.80      50.00         0.13    0.35
# 2   2021      2   23   207.20     0.16  29.20      49.80         0.89    0.27
# 3   2021      2   24   211.50     0.16  29.40      49.90         0.88    0.40
# 4   2021      2   25   194.60     0.14  23.60      50.00         0.85    0.66
# 5   2021      2   26   193.50     0.17  31.80      49.90         0.98    0.66
# 6   2021      2   27   188.20     0.14  22.50      50.00         0.86    0.64
# 7   2021      2   28   185.30     0.16  28.50      50.00         0.98    0.63
# 8   2021      3    1   191.50     0.17  31.00      50.00         0.98    0.49
# 9   2021      3    2   195.00     0.15  24.20      50.00         0.86    0.61
# 10  2021      3    3   195.40     0.15  25.00      50.00         0.87    0.65
# ...

# %%
X = data.drop("Energy",axis=1)   #Feature Matrix
y = data["Energy"]

# %%
X
# Out:
#     year  month  day  voltage  current  power  frequency  powerfactor
# 0   2021      2   20   202.30     0.03   0.80      50.00         0.13
# 1   2021      2   21   197.30     0.16  30.90      50.00         0.97
# 2   2021      2   22   200.40     0.03   0.80      50.00         0.13
# 3   2021      2   23   207.20     0.16  29.20      49.80         0.89
# 4   2021      2   24   211.50     0.16  29.40      49.90         0.88
# 5   2021      2   25   194.60     0.14  23.60      50.00         0.85
# 6   2021      2   26   193.50     0.17  31.80      49.90         0.98
# 7   2021      2   27   188.20     0.14  22.50      50.00         0.86
# 8   2021      2   28   185.30     0.16  28.50      50.00         0.98
# 9   2021      3    1   191.50     0.17  31.00      50.00         0.98
# 10  2021      3    2   195.00     0.15  24.20      50.00         0.86
# 11  2021      3    3   195.40     0.15  25.00      50.00         0.87
# ...

# %%
y
# Out:
# 0     0.35
# 1     0.26
# 2     0.35
# 3     0.27
# 4     0.40
# 5     0.66
# 6     0.66
# 7     0.64
# 8     0.63
# 9     0.49
# 10    0.61
# 11    0.65
# 12    0.47
# 13    0.48
# 14    0.51
# 15    0.82
# 16    0.69
# 17    0.76
# 18    0.36
# 19    0.52
# 20    0.03
# 21    0.22
# 22    0.61
# 23    0.46
# 24    0.19
# 25    0.21
# 26    0.40
# 27    0.64
# 28    0.63
# 29    0.63
# 30    0.59
# 31    0.62
# 32    0.60
# 33    0.60
# 34    0.62
# 35    0.62
# 36    0.61
# 37    0.62
# 38    0.62
# 39    0.63
# Name: Energy, dtype: float64

# %%
# separate dataset into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=0)

X_train.shape, X_test.shape
# Out:
# ((28, 8), (12, 8))

# %%
X_train.corr()
# Out:
#              year     month       day   voltage   current     power  \
# year          NaN       NaN       NaN       NaN       NaN       NaN
# month         NaN  1.000000 -0.607809  0.566846  0.041328  0.293884
# day           NaN -0.607809  1.000000  0.098282 -0.207952 -0.169248
# voltage       NaN  0.566846  0.098282  1.000000 -0.382801 -0.006479
# current       NaN  0.041328 -0.207952 -0.382801  1.000000  0.914409
# power         NaN  0.293884 -0.169248 -0.006479  0.914409  1.000000
# frequency     NaN  0.050358  0.072422  0.012697 -0.220120 -0.128139
# powerfactor   NaN  0.456011 -0.096110  0.217930  0.769454  0.939325
#
#              frequency  powerfactor
# year               NaN          NaN
# month         0.050358     0.456011
# day           0.072422    -0.096110
# voltage       0.012697     0.217930
# current      -0.220120     0.769454
# power        -0.128139     0.939325
# frequency     1.000000    -0.087086
# powerfactor  -0.087086     1.000000

# %%
import seaborn as sns
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor = X_train.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
# with the following function we can select highly correlated features
# it will remove the first feature that is correlated with anything other feature

def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X_train, 0.7)
len(set(corr_features))
# Out:
# 2

# %%
corr_features
# Out:
# {'power', 'powerfactor'}

# %%
X_train.drop(corr_features,axis=1)
X_test.drop(corr_features,axis=1)
# Out:
#     year  month  day  voltage  current  frequency
# 22  2021      3   15   230.80     0.12      50.00
# 20  2021      3   13   226.80     0.12      50.00
# 25  2021      3   20   218.40     0.12      49.90
# 4   2021      2   24   211.50     0.16      49.90
# 10  2021      3    2   195.00     0.15      50.00
# 15  2021      3    7   198.90     0.17      49.80
# 28  2021      3   23   222.83     0.12      49.97
# 11  2021      3    3   195.40     0.15      50.00
# 18  2021      3   10   190.70     0.16      49.90
# 29  2021      3   24   223.49     0.12      49.96
# 27  2021      3   22   230.80     0.12      49.90
# 35  2021      3   30   221.19     0.12      49.98

# %%
X = data[['voltage', 'current', 'power','frequency', 'powerfactor']]
X.head()
# Out:
#    voltage  current  power  frequency  powerfactor
# 0    202.3     0.03    0.8       50.0         0.13
# 1    197.3     0.16   30.9       50.0         0.97
# 2    200.4     0.03    0.8       50.0         0.13
# 3    207.2     0.16   29.2       49.8         0.89
# 4    211.5     0.16   29.4       49.9         0.88

# %%
y = data['Energy']
y.head()
# Out:
# 0    0.35
# 1    0.26
# 2    0.35
# 3    0.27
# 4    0.40
# Name: Energy, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((28, 5), (28,), (12, 5), (12,))
